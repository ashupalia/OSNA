# %%
from collections import Counter
import matplotlib.pyplot as plt
import networkx as nx
import sys
import time
from TwitterAPI import TwitterAPI
from nltk.tokenize import word_tokenize
import pandas as pd

def main():
    pos=0
    neg=0
    ps=pd.DataFrame(columns=['tweets', 'Id'])
    ns=pd.DataFrame(columns=['tweets', 'Id'])
    frame=pd.read_csv("train.csv",sep=',',encoding = "ISO-8859-1")
    print(frame.loc[800500])
    for i in range(0,499):
        row=frame.loc[i]
        l=[str(row[5]),0]
        ns.loc[len(ns)]=l
    for i in range(0,499):
        row=frame.loc[800000+i]
        l=[str(row[5]),1]
        ps.loc[len(ps)]=l

    print(ps)
    ps.to_csv("pos.csv",sep="\t",encoding="utf-8")
    ns.to_csv("neg.csv",sep="\t",encoding="utf-8")
    
if __name__ == '__main__':
    main()
# Out:
# 0                                                                                                                                                                      4
# 1467810369                                                                                                                                                    1467917329
# Mon Apr 06 22:19:45 PDT 2009                                                                                                                Mon Apr 06 22:48:11 PDT 2009
# NO_QUERY                                                                                                                                                        NO_QUERY
# _TheSpecialOne_                                                                                                                                                  ayam_me
# @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D    @CTesdahl well you can always digg or stumble....
# Name: 800500, dtype: object
#                                                 tweets Id
# 0    im meeting up with one of my besties tonight! ...  1
# 1    @DaRealSunisaKim Thanks for the Twitter add, S...  1
# 2    Being sick can be really cheap when it hurts t...  1
# 3      @LovesBrooklyn2 he has that effect on everyone   1
# 4    @ProductOfFear You can tell him that I just bu...  1
# 5    @r_keith_hill Thans for your response. Ihad al...  1
# 6    @KeepinUpWKris I am so jealous, hope you had a...  1
# 7    @tommcfly ah, congrats mr fletcher for finally...  1
# 8    @e4VoIP I RESPONDED  Stupid cat is helping me ...  1
# 9    crazy day of school. there for 10 hours straii...  1
# 10   @naughtyhaughty HOW DID I FORGET ABOUT TWO AND...  1
# 11   @nileyjileyluver Haha, don't worry! You'll get...  1
# 12   @soundwav2010 At least I won't be the only one...  1
# 13   @LutheranLucciol Make sure you DM me if you po...  1
# 14                Just added tweetie to my new iPhone   1
# 15   @michellardi i really don't know. i think its ...  1
# 16          @nicolerichie: your picture is very sweet   1
# 17   Catching Up on Emails, RSS and Random BACN. Th...  1
# 18   Dancing around the room in Pjs, jamming to my ...  1
# 19   Didn't place in the Peeps contest but thanks f...  1
# 20   Going to bed so goodnight everyone  and sweet ...  1
# 21   @LittleLumen walking over to put the deposit d...  1
# 22   is now followinq @DAChesterFrench , you shud d...  1
# 23   @LordPov Are you meant to add on the back of t...  1
# 24   Aw i'm holding my new puppy. Well He's not min...  1
# 25   @iJohn kitteh is sleepin on my crotch which pr...  1
# 26                                 @DramaBeats agreed   1
# 27   reaching amritsar in an hour and (if i find a ...  1
# 28   @ALBinLA.  I was just thinking about you tonig...  1
# 29               happy to spend time with the family.   1
# ..                                                 ... ..
# 469                               @Croconaw goodnight   1
# 470  @danielkirkley Lead Me To The Cross is one of ...  1
# 471  just got back from starbucks.. tried the tea w...  1
# 472                                BOOM BOOM POW-oops   1
# 473         The Super Red Diva !!!  Stupid University   1
# 474  This latest episode of NewNowNext is like full...  1
# 475  When you just want things to end, remember to ...  1
# 476  @ PBnJen : Thanks for the great tour and makin...  1
# 477  @DonnieWahlberg YOU give me joy....and you hav...  1
# 478  @tothepc Did you check out http://www.weboword...  1
# 479  Artistic affirmation from a drunk lady was kin...  1
# 480  @Honey3223  Honey goodnight I am up really ear...  1
# 481  A je kakï¿½en rip od Trenutek resnice? Link, l...  1
# 482  Lamb Chowmein for dinner tonight.... hhhmmm wi...  1
# 483  tweeting from my brand new Sony PSP... just be...  1
# 484  @MussoMitchel Hey you should go on tour someti...  1
# 485  well tweeps, im off, i gotta have a shower the...  1
# 486  @juliaroy I've just seen your Flickr and I've ...  1
# 487  @danielc Sorry it wasn't Wrath of Khan.  But w...  1
# 488  juggernaut, dr. doom, magneto, &amp; xavier!  ...  1
# 489  @ricardooooo we'll have a geek off next time y...  1
# 490                            aww dont make me blush!  1
# 491                   trying to figure this thing out   1
# 492  watching &quot;The Princess Bride&quot; I want...  1
# 493  @lisaholmes you can buy my fiances duplex in T...  1
# 494  @apleaforaaron i could really eat some cheese ...  1
# 495  @ddlovato I am so FUCKING jealous of you girl....  1
# 496  @ThaStevieG my bunnys name was Lucy  you can g...  1
# 497  @pixelpipe any updates for iPhone OS 3.0 yet? ...  1
# 498                               Denise, I love you.   1
#
# [499 rows x 2 columns]
